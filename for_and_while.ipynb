# %%
secret = 3 #pretend this is a random number between 1 and 10
guess = int(input("Enter a number between 1 and 10"))
if guess > secret:
    print("Too high")
if guess < secret:
    print ("Too low")
if guess == secret:
    print("Just right")
# Out:
# Enter a number between 1 and 10 4
# Too high
