# %%
things = ["mozzarella", "cinderella", "salmonella"] # 7.4 creating the "ella" list

for word in things:
    print(word)

things[1] = things[1].capitalize() # 7.5 making the thing that refers to a person uppercase

for word in things:
    print(word) # 7.5 the list has indeed changed

things[0] = things[0].upper() # 7.6 making the cheesy thing in the list all uppercase

for word in things:
    print(word) # 7.6 the list has indeed changed

things.pop(2) # 7.6 removing the disease

for word in things: # 7.6 the disease has been removed
    print(word)

def good(): # 9.1 created a function that returns Harry, Ron, and Hermione
    return ['Harry', 'Ron', 'Hermione']

def get_odds(): # 9.2 created get_odds function
    odds = []
    for x in range(10):
        if x % 2 == 1:
            odds.append(x)
    return odds

loops = 0
for x in get_odds(): # 9.2 found the third number returned by get_odds
    loops += 1
    if loops == 3:
        print(x)
