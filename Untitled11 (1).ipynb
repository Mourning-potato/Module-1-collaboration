# %%
from fileinput import close

from datetime import date
from datetime import datetime

with open("today.txt", "w") as f: # 13.1
    print(str(date.today()), file=f)

    f.close()

with open("today.txt", "r") as f: # 13.2
    today_string = f.read()

year = today_string[:4] # 13.3
today_string = today_string[5:]

month = today_string[:2]
today_string = today_string[3:]

day = today_string[:2]

print("year: " + year)
print("month: " + month)
print("day: " + day)

import multiprocessing # 15.1
import time
import random
import os

def little_man(number):
    time.sleep(random.randint(0,5))
    print(datetime.now())

if __name__ == "__main__":
    for n in range(3):
        p = multiprocessing.Process(target=little_man,
          args=(n,))
        p.start()
# Out:
# year: 2025
# month: 12
# day: 03
